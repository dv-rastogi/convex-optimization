# %% [markdown]
# # COO Coding Assigment
# ### Name: Divyansh Rastogi
# ### Roll: 2019464
# ### Question: 3

# %%
import numpy as np 
import scipy.optimize
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Setting up portfolio investment problem
# - We use `scipy.optimize.minimze` for constrained minimization.
# - Method used `SLSQP`
# #### [docs for scipy.minimize](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html)
# #### [docs for SLSQP](https://docs.scipy.org/doc/scipy/reference/tutorial/optimize.html#sequential-least-squares-programming-slsqp-algorithm-method-slsqp)

# %%
class PortfolioOptimization:
    def __init__(self, n, B=1, r_min=None, m=None, V=None, idV=True):
        '''
        params:
            n: number of assets
            B: total wealth
            r_min: minimum acceptable mean return
        
        fractional return vector params:
            m: mean vector 
            V: covariance
         '''

        self.n = n
        self.B = B 
        self.r_min = (5*B/100) if r_min is None else r_min 
        # In case min return not specificed, take it to be 5% of total investement

        if m is None:
            self.m = 2 * np.random.rand(n) - 0.25
        else:
            self.m = m
        
        if V is None and idV:
            self.V = np.identity(n) # has to be symmetric
        elif V is None:
            t = 2 * np.random.rand(n, n) +  np.identity(n) - 1
            self.V = np.dot(t, t.T)
        else:
            assert(np.all(V == V.T))
            self.V = V

    # minimize 
    def f(x, *args):
        po = args[0]
        # assert (isinstance(po, PortfolioOptimization))
        return x.dot(po.V @ x)

    # gradient vector of f
    def jac_f(x, *args):
        po = args[0]
        # assert (isinstance(po, PortfolioOptimization))
        return 2 * (po.V @ x)

    # minimum acceptable mean return
    # f_r_min(x) >= 0
    def f_r_min(x, *args):
        po = args[0]
        # assert (isinstance(po, PortfolioOptimization))
        return np.array([x.dot(po.m) - po.r_min])

    def jac_f_r_min(x, *args):
        po = args[0]
        # assert (isinstance(po, PortfolioOptimization))
        return po.m.copy()

    # total investment should sum to B
    def f_tot(x, *args):
        po = args[0]
        # assert (isinstance(po, PortfolioOptimization))
        return np.array(np.sum(x) - po.B)
    
    def jac_f_tot(x, *args):
        return np.ones_like(x)

    def run(self, x0=None):

        bounds = scipy.optimize.Bounds(0, np.inf)

        ineq_cons = {
            'type': 'ineq',
            'fun': PortfolioOptimization.f_r_min,
            'jac': PortfolioOptimization.jac_f_r_min,
            'args': (self,)
        }

        eq_cons = {
            'type': 'eq',
            'fun': PortfolioOptimization.f_tot,
            'jac': PortfolioOptimization.jac_f_tot,
            'args': (self,)
        }

        if x0 is None:
            x0 = np.random.rand(self.n)
            x0 /= sum(x0)

        res = scipy.optimize.minimize(
            PortfolioOptimization.f,
            x0,
            method='SLSQP',
            jac=PortfolioOptimization.jac_f,
            constraints=(eq_cons, ineq_cons),
            bounds=bounds,
            options={'disp': True},
            args=(self,)
        )

        return res

# %% [markdown]
# ## Part 2
# - min return is taken to be 5% of total wealth
# - `m` and `V` are chosen as specified in class `PortfolioOptimization`
# - `V` is chosen as a positive semi definite matrix to make our optimization convex
# - `m` can have some negative values, simulating drop in prices

# %%
po = PortfolioOptimization(n=20, idV=False)
print(f"Chosen m: {po.m}")
print(f"Chosen V: {po.V}")
# Out:
# Chosen m: [ 0.8071282   1.09481957  1.25388192  0.70072582  1.28415553  1.29082993
-02, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.81259291e-02, 1.25898125e-01, 8.67988621e-02, 9.77305552e-02,
#        6.17356431e-02, 4.55394394e-02, 0.00000000e+00, 3.27700862e-02])

# %%
# Cross checking inequality constraints >= 0
PortfolioOptimization.f_r_min(res.x, po)
# Out:
# array([0.79379618])

# %%
# Cross checking equality constraints = 0
PortfolioOptimization.f_tot(res.x, po)
# Out:
# array(2.22044605e-16)

# %% [markdown]
# ## Part 3
# - `min_target_returns` is upper-bounded on 1 for `m` (mean fractional return) to be upper-bounded on 1.25
# - Thereby, we simulate maximum & minimum mean increase in asset to be 125% and -25% respectively, while varying min returns to be from 0% to 100%
# - `V` is chosen as a positive semi definite matrix with maximum covariance of 1.

# %%
# Choosing returns from 0% to 100%
min_target_returns = np.linspace(0, 1, num=200)

n = 20
# Choosing fractional return mean and covariance
m = 1.5 * np.random.rand(n) - 0.25
t = np.random.rand(n, n)
V = np.dot(t, t.T)

# Calculating risks
risks = []
returns = []
for y in min_target_returns:
    po_obj = PortfolioOptimization(n=n, r_min=y, m=m, V=V)
    opt = po_obj.run().x
    risks.append(PortfolioOptimization.f(opt, po_obj)) 
    returns.append(PortfolioOptimization.f_r_min(opt, po_obj)[0] + y)
    print("Ineq constraint: ", PortfolioOptimization.f_r_min(opt, po_obj)[0])
    print("Eq constraint: ", PortfolioOptimization.f_tot(opt, po_obj))
    assert(PortfolioOptimization.f_r_min(opt, po_obj)[0] >= -1e-8)
    assert(PortfolioOptimization.f_tot(opt, po_obj) < 1e-8)
# Out:
# .    (Exit mode 0)
#             Current function value: 2.9408838088573095
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  5.717648576819556e-14
# Eq constraint:  9.348077867343818e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.946419053696655
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  1.021405182655144e-14
# Eq constraint:  4.1300296516055823e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9519850981387523
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  1.84297022087776e-14
# Eq constraint:  2.886579864025407e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.957581942183758
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  5.984102102729594e-14
# Eq constraint:  1.2612133559741778e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9632095858302603
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  4.5630166312093934e-14
# Eq constraint:  4.729550084903167e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9688680290793172
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  1.9095836023552692e-14
# Eq constraint:  5.3290705182007514e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9745572719308386
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  2.8976820942716586e-14
# Eq constraint:  2.864375403532904e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9802773143846584
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  2.2093438190040615e-14
# Eq constraint:  2.020605904817785e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.986028156440885
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  1.7208456881689926e-14
# Eq constraint:  1.3766765505351941e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9918097980994554
#             Iterations: 7
#             Function evaluations: 8
#             Gradient evaluations: 7
# Ineq constraint:  4.218847493575595e-15
# Eq constraint:  9.769962616701378e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.997622239360571
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  1.865174681370263e-14
# Eq constraint:  1.7541523789077473e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0034654802242065
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  1.0769163338864018e-14
# Eq constraint:  6.705747068735946e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.009339520689746
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  2.1871393585115584e-14
# Eq constraint:  2.2426505097428162e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.015244360757797
#             Iterations: 5
#             Function evaluations: 6
#             Gradient evaluations: 5
# Ineq constraint:  -1.887379141862766e-15
# Eq constraint:  2.886579864025407e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0211802898263826
#             Iterations: 3
#             Function evaluations: 5
#             Gradient evaluations: 3
# Ineq constraint:  8.770761894538737e-15
# Eq constraint:  9.103828801926284e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0271641668714775
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.2290168882600483e-13
# Eq constraint:  2.915445662665661e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0332273608347964
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  3.1308289294429414e-14
# Eq constraint:  6.59472476627343e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.039370110956719
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  6.483702463810914e-14
# Eq constraint:  9.814371537686384e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0455924172372377
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  2.7988722450800196e-13
# Eq constraint:  6.150635556423367e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0518942796692228
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.000310945187266e-13
# Eq constraint:  2.149391775674303e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.05827569826034
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.0158540675320182e-13
# Eq constraint:  2.4558133304708463e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  2.7200464103316335e-14
# Eq constraint:  3.219646771412954e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.3981344884534312
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.3988810110276972e-13
# Eq constraint:  2.993161274389422e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.407936821776764
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.6697754290362354e-13
# Eq constraint:  1.9806378759312793e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.4178187112566505
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.8496315590255108e-13
# Eq constraint:  4.005684672847565e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.427780156891225
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  6.7390537594747e-14
# Eq constraint:  8.704148513061227e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.437821158683017
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  3.3306690738754696e-15
# Eq constraint:  3.2862601528904634e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.4479417166331032
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  4.884981308350689e-14
# Eq constraint:  1.6253665080512292e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.458141830739742
#             Iterations: 3
#             Function evaluations: 4
#             Gradient evaluations: 3
# Ineq constraint:  1.2423395645555502e-13
# Eq constraint:  1.4988010832439613e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.468421501000407
#             Iterations: 4
#             Function evaluations: 4
#             Gradient evaluations: 4
# Ineq constraint:  1.9539925233402755e-14
# Eq constraint:  3.397282455352979e-14

# %%
# Plotting risks vs returns
plt.plot(returns, risks)
plt.ylabel('risk')
plt.xlabel('return')
plt.title('return vs risk')
plt.show()

# %%
# Plotting risks vs min return
plt.plot(min_target_returns, risks)
plt.ylabel('risk')
plt.xlabel('return')
plt.title('min return vs risk')
plt.show()

# %%
# Plotting risks vs returns, min return
plt.plot(risks, min_target_returns, '--g', label='min return')
plt.plot(risks, returns, 'r', label='return')
plt.xlabel('risk')
plt.ylabel('return')
plt.title('risk vs return, min return')
plt.legend()
plt.show()

# %% [markdown]
# ## Bonus
# Distributional assumptions used to generate `m` **affects** final solution obtained.
# As `m` denotes the mean fractional return, our current mean distribution ensures that *every* return from `min_target_returns` is comparitively probabilisticly achievable.
# - Current returns fall in range of 0% --> 100%
# - Current fractional mean returns falls in range of -25% --> 125%
#
# Now we take `m` to be a vector which highers the probability of achieving our minimum returns even more
# - New fractional mean returns falls in range of 0% --> 175%
#
# **We observe** that for the same min-return, we are getting a lower risk in our new setting as compared to the previous setting i.e. *higher fractional return mean implies a lower risk for a given min-return*
#
# #### Note for bonus analysis: For comparison with previous results, `V`, `n`, `min_target_returns` stays same as above.

# %%
# Choosing new fractional return mean
# Note the maximum and minimum values of m
m = 1.75 * np.random.rand(n)

# Calculating risks
risks = []
returns = []
for y in min_target_returns:
    po_obj = PortfolioOptimization(n=n, r_min=y, m=m, V=V)
    opt = po_obj.run().x
    risks.append(PortfolioOptimization.f(opt, po_obj)) 
    returns.append(PortfolioOptimization.f_r_min(opt, po_obj)[0] + y)
    print("Ineq constraint: ", PortfolioOptimization.f_r_min(opt, po_obj)[0])
    print("Eq constraint: ", PortfolioOptimization.f_tot(opt, po_obj))
    assert(PortfolioOptimization.f_r_min(opt, po_obj)[0] >= -1e-8)
    assert(PortfolioOptimization.f_tot(opt, po_obj) < 1e-8)
# Out:
# it mode 0)
#             Current function value: 2.7204652874920483
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Ineq constraint:  9.992007221626409e-15
# Eq constraint:  9.992007221626409e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.7258238450484398
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Ineq constraint:  3.1086244689504383e-15
# Eq constraint:  1.2656542480726785e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.7312204828997566
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Ineq constraint:  1.3433698597964394e-14
# Eq constraint:  1.8207657603852567e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.736653380230203
#             Iterations: 7
#             Function evaluations: 8
#             Gradient evaluations: 7
# Ineq constraint:  1.5210055437364645e-14
# Eq constraint:  1.9539925233402755e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  7.260858581048524e-14
# Eq constraint:  8.348877145181177e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9638698873277414
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  2.5868196473766147e-14
# Eq constraint:  3.3084646133829665e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.970718472684251
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  3.042011087472929e-14
# Eq constraint:  3.930189507173054e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9776043000745496
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  1.4432899320127035e-14
# Eq constraint:  1.9984014443252818e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9845274214518174
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  9.547918011776346e-15
# Eq constraint:  9.547918011776346e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9914876809588797
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  1.2656542480726785e-13
# Eq constraint:  1.9384494009955233e-13
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.9984852435804825
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  1.7430501486614958e-14
# Eq constraint:  2.731148640577885e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0055192694873987
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  3.7969627442180354e-14
# Eq constraint:  5.573319583618286e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.012640683466684
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  1.2101430968414206e-14
# Eq constraint:  1.5987211554602254e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0198846249419504
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  1.9206858326015208e-14
# Eq constraint:  2.3314683517128287e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.027251093913219
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  4.030109579389318e-14
# Eq constraint:  4.951594689828198e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0347400903797754
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  9.658940314238862e-15
# Eq constraint:  1.1324274851176597e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0423516143422655
#             Iterations: 4
#             Function evaluations: 6
#             Gradient evaluations: 4
# Ineq constraint:  7.815970093361102e-14
# Eq constraint:  8.970602038971265e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0500856658255104
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  6.994405055138486e-15
# Eq constraint:  1.2212453270876722e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.0579422448055182
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  1.5654144647214707e-14
# Eq constraint:  2.0650148258027912e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.065921358316853
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  4.773959005888173e-15
# Eq constraint:  7.105427357601002e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.074022985273052
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Ineq constraint:  3.785860513971784e-14
# Eq constraint:  5.040412531798211e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.082247151415195
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  3.697042672001771e-14
# Eq constraint:  4.796163466380676e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.09059383666089
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  6.428191312579656e-14
# Eq constraint:  7.904787935331115e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.099063053718286
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  1.6986412276764895e-14
# Eq constraint:  2.2648549702353193e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1076548024286335
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  4.6851411639181606e-14
# Eq constraint:  6.150635556423367e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1163690760587435
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  2.4313884239290928e-14
# Eq constraint:  3.3084646133829665e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1252062467216586
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Ineq constraint:  4.9960036108132044e-15
# Eq constraint:  6.439293542825908e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1341652375089457
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  3.497202527569243e-14
# Eq constraint:  4.6407322429331543e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1432470516975872
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  2.5202062658991053e-14
# Eq constraint:  3.441691376337985e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.152451429992139
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Ineq constraint:  1.2878587085651816e-14
# Eq constraint:  1.9095836023552692e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.161778336857355
#             Iterations: 6
#             Function evaluations: 8
#             Gradient evaluations: 6
# Ineq constraint:  3.652633751016765e-14
# Eq constraint:  4.618527782440651e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.171227775187575
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Ineq constraint:  2.5202062658991053e-14
# Eq constraint:  2.842170943040401e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.180799830086389
#             Iterations: 6
#             Function evaluations: 6
#             Gradient evaluations: 6
# Ineq constraint:  2.020605904817785e-14
# Eq constraint:  2.2870594307278225e-14
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.1904944142172282
#             Iterations: 6
#             Function evaluations: 7
#             Gradient evaluations: 6
# Ineq constraint:  4.440892098500626e-15
# Eq constraint:  7.327471962526033e-15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.2003113078416594
#             Iterations: 7
#             Function evaluations: 7
#             Gradient evaluations: 7
# Ineq constraint:  6.772360450213455e-14
# Eq constraint:  7.549516567451064e-14

# %%
# Plotting risks vs returns, min return
plt.plot(risks, min_target_returns, '--g', label='min return')
plt.plot(risks, returns, 'r', label='return')
plt.xlabel('risk')
plt.ylabel('return')
plt.title('risk vs return, min return [with higher fractional return mean]')
plt.legend()
plt.show()
